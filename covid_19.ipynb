# %% [markdown]
# <a href="https://colab.research.google.com/github/rachitbhatt16/Projects/blob/Covid_19/covid_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  **Importing Necessary Libraries**

# %%
# !pip install -U plotly

# %%
# Data analysis and Manipulation
import plotly.graph_objs as go
import plotly.io as pio
import plotly.express as px
import pandas as pd

# Data Visualization
import matplotlib.pyplot as plt

# Importing Plotly
import plotly.offline as py
py.init_notebook_mode(connected=True)

# Initializing Plotly
pio.renderers.default = 'colab'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>

# %% [markdown]
# **Importing the Datasets**

# %%
# Importing Dataset1
dataset1 = pd.read_csv("/content/drive/MyDrive/covid (1).csv")
dataset1.head(4)  # returns first 5 rows
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-7-881075930.py in <cell line: 0>()
#       1 # Importing Dataset1
# ----> 2 dataset1 = pd.read_csv("/content/drive/MyDrive/covid (1).csv")
#       3 dataset1.head(4)  # returns first 5 rows
#
# ...

# %% [markdown]
# **getting dataset information**

# %%
# Returns tuple of shape (Rows, columns)
print(dataset1.shape)

# Returns size of dataframe
print(dataset1.size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-8-3685334665.py in <cell line: 0>()
#       1 # Returns tuple of shape (Rows, columns)
# ----> 2 print(dataset1.shape)
#       3
#       4 # Returns size of dataframe
#       5 print(dataset1.size)
#
# NameError: name 'dataset1' is not defined

# %% [markdown]
# dataset **information**

# %%
dataset1.info()

# %% [markdown]
# importing all data set

# %%
dataset2 = pd.read_csv("/content/drive/MyDrive/covid_grouped (1).csv")
dataset3 = pd.read_csv("/content/drive/MyDrive/coviddeath (1).csv")

# %%
dataset2.head(4)  # returns first 5 rows

# %%
dataset3.head(4)  # returns first 5 rows

# %% [markdown]
# dataset colum

# %%
import pandas as pd
dataset1 = pd.read_csv("/content/drive/MyDrive/covid (1).csv")
dataset1.columns

# %% [markdown]
# cleaning dataframe

# %%
dataset1.drop(['NewCases', 'NewDeaths', 'NewRecovered'],
         axis = 1, inplace = True)
dataset1.sample(5)

# %% [markdown]
# creatin table using plotly express

# %%
# Import create_table Figure Factory
import plotly.offline as py
py.init_notebook_mode(connected=True)
from plotly.figure_factory import create_table

colorscale = [[0, '#4d004c'], [.5, '#f2e5ff'], [1, '#ffffff']]
table = create_table(dataset1.head(15), colorscale=colorscale)
py.iplot(table)

# %% [markdown]
# Bargraph

# %%
import plotly.express as px
px.bar(dataset1.head(15), x = 'Country/Region', y = 'TotalCases', color = 'TotalCases',height = 500 , hover_data = ['Country/Region', 'Continent', 'TotalCases', 'TotalDeaths', 'TotalRecovered'])

# %% [markdown]
# **Bar Graph**

# %%
px.bar(dataset1.head(15), x = 'Country/Region', y = 'TotalCases',
       color = 'TotalDeaths', height = 500,
       hover_data = ['Country/Region', 'Continent'])

# %% [markdown]
# **bar graph**

# %%
px.bar(dataset1.head(15), x = 'TotalTests', y = 'Country/Region',
       color = 'TotalTests',orientation ='h',  height = 500,
       hover_data = ['Country/Region', 'Continent'])

# %% [markdown]
# **Data Visualization through Bubble Charts-Continent Wise**

# %%
px.scatter(dataset1, x='Continent',y='TotalCases',
           hover_data=['Country/Region', 'Continent'],
           color='TotalCases', size='TotalCases', size_max=40)

# %% [markdown]
# **Scatter plot**

# %%
px.scatter(dataset1.head(40), x='Continent',y='TotalCases',
           hover_data=['Country/Region', 'Continent'],
           color='TotalCases', size='TotalCases', size_max=30, log_y=True)

# %% [markdown]
# **Data Visualization through Bubble Charts-Country Wise**

# %%
px.scatter(dataset1.head(70), x='Country/Region', y='TotalCases',
           hover_data=['Country/Region', 'Continent'],
           color='TotalCases', size='TotalCases', size_max=50)

# %% [markdown]
# **Bubble Chart**

# %%
px.scatter(dataset1.head(20), x='Country/Region', y='TotalCases',
           hover_data=['Country/Region', 'Continent'],
           color='Country/Region', size='TotalCases', size_max=40, log_y=True)

# %%
px.scatter(dataset1.head(30), x='Country/Region', y= 'Tests/1M pop',
           hover_data=['Country/Region', 'Continent'],
           color='Country/Region', size= 'Tests/1M pop', size_max=80)

# %% [markdown]
# **Country/Region VS Tests/1M pop (color-scale of Tests/1M**

# %%
px.scatter(dataset1.head(30), x='Country/Region', y= 'Tests/1M pop',
           hover_data=['Country/Region', 'Continent'],
           color='Tests/1M pop', size= 'Tests/1M pop', size_max=80)

# %% [markdown]
# **Bubble Chart**

# %%
px.scatter(dataset1.head(30), x='TotalCases', y= 'TotalDeaths',
           hover_data=['Country/Region', 'Continent'],
           color='TotalDeaths', size= 'TotalDeaths', size_max=80)

# %%
px.scatter(dataset1.head(30), x='TotalCases', y= 'TotalDeaths',
           hover_data=['Country/Region', 'Continent'],
           color='TotalDeaths', size= 'TotalDeaths', size_max=80,
           log_x=True, log_y=True)
